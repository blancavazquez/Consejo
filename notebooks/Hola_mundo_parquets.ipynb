# %% [markdown]
# ## Práctica con parquet
# El objetivo de esta libreta es aprender los conceptos básicos de parquets, dataframes y RDDS sobre Databricks usando Pyspark y Scala.

# %% [markdown]
# # Nivel básico
#
# Estructuras de datos:
# - RDDs (Resilient Distributed Dataset): son una colección de datos tolerantes a fallos y que trabajan de forma paralela.
#   * Es la abstracción de datos más básica en Spark.
#   * Están particionados sobre los nodos del clúster.
#   * Son inmutables: cuando transformamos un RDD realmente estamos creado uno nuevo.
#   * Distribuye los datos en modo lectura.
#
# - Dataframe: es un conjunto de datos organizado en columnas.
#   * Trabajan de forma paralela.
#
# - Parquet: es un almacenamiento basado en columnas
#   * Los datos se almacenan en columnas en lugar de filas.
#   * Se selecciona solo las columnas necesarias para la consulta.
#   * Parquet es formato binario, garantizando la serialización efectiva y deserialización de los datos.
#   * Los metadatos se almacenan después de escribir los datos en el pie de página capturando las estadísticas resumidas de los fragmentos de la columna.
#
#   <img src="https://miro.medium.com/v2/resize:fit:4800/format:webp/1*X9wL6xlATJsAru7N5u-IEA.png"  width="40%" height="40%">
#
#   <img src="https://1.bp.blogspot.com/-EBTMgn05zVU/XjpzbFcS2pI/AAAAAAAAA_8/8E_IHuumv6cTgQnnwQwEbNwouMvyz331gCLcBGAsYHQ/s1600/file_struct.JPG"  width="30%" height="30%">

# %%
# Modo terminal (magic funcion)
# %pwd
# %ls
# Out:
# azure/  eventlogs/  hadoop_accessed_config.lst*  metastore_db/
# conf/   ganglia/    logs/                        preload_class.lst*

# %% [markdown]
# #### 1) Crear una estructura de datos y guardarla como parquet usando Scala

# %%
# %scala 
case class fifa20(nombre: String, club: String)
val df_scala = Seq(new fifa20("L. Messi","FC Barcelona"), 
                   new fifa20("Cristiano Ronaldo", "Juventus"), 
                   new fifa20("Neymar Jr", "Paris Saint-Germain")).toDF

display(df_scala) //revisando el contenido del dataframe creado
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nombre</th><th>club</th></tr></thead><tbody><tr><td>L. Messi</td><td>FC Barcelona</td></tr><tr><td>Cristiano Ronaldo</td><td>Juventus</td></tr><tr><td>Neymar Jr</td><td>Paris Saint-Germain</td></tr></tbody></table></div>

# %%
# %scala 
df_scala.write.mode("overwrite").parquet("/tmp/FIFA_Parquet") //guardamos el df a disco como parquet
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### 2) Carga de un archivo parquet con python

# %%
df_python = spark.read.parquet("/tmp/FIFA_Parquet")
print(type(df_python))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
df_python.show() #visualizando el contenido del dataframe
# Out:
# +-----------------+-------------------+
# |           nombre|               club|
# +-----------------+-------------------+
# |        Neymar Jr|Paris Saint-Germain|
# |Cristiano Ronaldo|           Juventus|
# |         L. Messi|       FC Barcelona|
# +-----------------+-------------------+

# %%
#renombrar una columna
df_python.withColumnRenamed('nombre','jugador').show() #esto no afectará al dataframe original
# Out:
# +-----------------+-------------------+
# |          jugador|               club|
# +-----------------+-------------------+
# |        Neymar Jr|Paris Saint-Germain|
# |Cristiano Ronaldo|           Juventus|
# |         L. Messi|       FC Barcelona|
# +-----------------+-------------------+

# %%
#Para poder revisar la organización de nuestro DataFrame y el data type de cada campo podemos usarlo siguiente
df_python.printSchema()
# Out:
# root
#  |-- nombre: string (nullable = true)
#  |-- club: string (nullable = true)

# %% [markdown]
# #### 3) Carga de un archivo parquet con SQL

# %%
# %sql 
CREATE TABLE tabla_fifa
USING parquet
OPTIONS (path "/tmp/FIFA_Parquet")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
SELECT * FROM tabla_fifa
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nombre</th><th>club</th></tr></thead><tbody><tr><td>Neymar Jr</td><td>Paris Saint-Germain</td></tr><tr><td>Cristiano Ronaldo</td><td>Juventus</td></tr><tr><td>L. Messi</td><td>FC Barcelona</td></tr></tbody></table></div>

# %%
consulta = '''
  SELECT nombre AS jugador 
  FROM tabla_fifa
  where club = "Juventus"
  '''
spark.sql(consulta).show()
# Out:
# +-----------------+
# |          jugador|
# +-----------------+
# |Cristiano Ronaldo|
# +-----------------+

# %% [markdown]
# # Nivel intermedio

# %% [markdown]
# #### ¿Qué es PySpark?
# PySpark es una herramienta que nos deja usar Spark encima de Python. Permitiendonos combinar el proceso de datos distribuidos de Spark con la simplicidad de Python para el análisis de conjuntos masivos de datos (big data).

# %%
#Carga de la biblioteca
import pyspark
# Carga funciones extra
from pyspark.sql.functions import * 
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('primeros_pasos').getOrCreate()

# %%
# %scala
//Carga de un archivo parquet
val clickstream = sqlContext.read.parquet("/datasets/wiki-clickstream/part-00000-tid-3267700592912152934-af798f24-a539-4dbb-8419-1799463dc63a-664-1-c000.snappy.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">clickstream: org.apache.spark.sql.DataFrame = [prev_id: int, curr_id: int ... 4 more fields]
# </div>

# %%
df_stream = spark.read.parquet("/datasets/wiki-clickstream/part-00004-tid-3267700592912152934-af798f24-a539-4dbb-8419-1799463dc63a-668-1-c000.snappy.parquet")
print(type(df_stream))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
df_stream.show(100)
# Out:
# +--------+--------+---+--------------------+--------------------+-------+
# | prev_id| curr_id|  n|          prev_title|          curr_title|   type|
# +--------+--------+---+--------------------+--------------------+-------+
# |    null|30132352|306|        other-google|So_Beautiful_or_S...|  other|
# |    null|30132352|168|     other-wikipedia|So_Beautiful_or_S...|  other|
# | 2048277|30132352| 15|Still_Crazy_After...|So_Beautiful_or_S...|   link|
# | 4980756|30132352| 43|Surprise_(Paul_Si...|So_Beautiful_or_S...|   link|
# |23617892|30132352|240|The_Essential_Pau...|So_Beautiful_or_S...|   link|
# |    null|30132352| 68|         other-empty|So_Beautiful_or_S...|  other|
# |  147605|30132352| 11|  Paul_Simon_(album)|So_Beautiful_or_S...|   link|
# |    null|30132352| 11|         other-yahoo|So_Beautiful_or_S...|  other|
# |15580374|30132352| 11|           Main_Page|So_Beautiful_or_S...|  other|
# |18422066|30132352|299|Paul_Simon_discog...|So_Beautiful_or_S...|   link|
# |   50745|30132352|732|          Paul_Simon|So_Beautiful_or_S...|   link|
# |    null|30132352| 21|         other-other|So_Beautiful_or_S...|  other|
# | 1213541|30132352| 11|You're_the_One_(a...|So_Beautiful_or_S...|   link|
# |  399532|30132352| 13|The_Rhythm_of_the...|So_Beautiful_or_S...|   link|
# |    null|26329260| 15|     other-wikipedia|So_Ben_Mi_Chi_Ha_...|  other|
# |    null|26329260| 11|        other-google|So_Ben_Mi_Chi_Ha_...|  other|
# |    null|22132828| 40|        other-google|  So_Big_(1953_film)|  other|
# |24613251|22132828| 13|Sterling_Hayden_f...|  So_Big_(1953_film)|   link|
# |   67757|22132828| 20|         Robert_Wise|  So_Big_(1953_film)|   link|
# | 1468604|22132828| 13|         Nancy_Olson|  So_Big_(1953_film)|   link|
# |  183753|22132828| 23|          Jane_Wyman|  So_Big_(1953_film)|   link|
# | 1549374|22132828| 11|          Ken_Osmond|  So_Big_(1953_film)|   link|
# | 1727632|22132828| 20|      Richard_Beymer|  So_Big_(1953_film)|   link|
# | 1268236|22132828| 22|         Martha_Hyer|  So_Big_(1953_film)|   link|
# | 1765552|22132828| 14|        Tommy_Rettig|  So_Big_(1953_film)|   link|
# | 1591611|22132828| 38|Steve_Forrest_(ac...|  So_Big_(1953_film)|   link|
# |    null|22132828| 39|         other-empty|  So_Big_(1953_film)|  other|
# |25837203|28841901| 31| Replay_(Iyaz_album)|       So_Big_(song)|   link|
# |    null|28841901| 13|         other-empty|       So_Big_(song)|  other|
# |    null|28841901|112|        other-google|       So_Big_(song)|  other|
# |24599548|28841901| 37|                Iyaz|       So_Big_(song)|   link|
# |25787622|28841901| 20|      Pyramid_(song)|       So_Big_(song)|   link|
# |    null| 3569444| 22|         other-empty|              So_Blu|  other|
# | 5184081| 3569444|119|Hit_'Em_Up_Style_...|              So_Blu|   link|
# | 3569609| 3569444| 25|Bittersweet_(Blu_...|              So_Blu|   link|
# |  168873| 3569444|267|        Blu_Cantrell|              So_Blu|   link|
# |34157606| 3569444| 77|Blu_Cantrell_disc...|              So_Blu|   link|
# |    null| 3569444| 42|        other-google|              So_Blu|  other|
# |    null|41379891|104|        other-google| So_Blue_(Akon_song)|  other|
# |    null|41379891| 23|         other-empty| So_Blue_(Akon_song)|  other|
# |    null|41379891| 14|     other-wikipedia| So_Blue_(Akon_song)|  other|
# |42755122|41379891| 20|             So_Blue| So_Blue_(Akon_song)|   link|
# | 5570621|41379891|146|                Akon| So_Blue_(Akon_song)|   link|
# | 8711384|41379891|123|    Akon_discography| So_Blue_(Akon_song)|   link|
# |    null|43077031| 13|        other-google|So_Bright_Is_the_...|  other|
# |    null| 2864946| 12|        other-google|    So_Cal_Scorpions|  other|
# |    null| 2864946| 11|         other-empty|    So_Cal_Scorpions|  other|
# |  548951| 2864946| 32|Women's_Professio...|    So_Cal_Scorpions|   link|
# |32753032|13969544| 10|      Reza_Mirkarimi|    So_Close,_So_Far|   link|
# |11573972|13969544| 25|List_of_Iranian_f...|    So_Close,_So_Far|   link|
# |19625976|13969544| 15|List_of_Iranian_s...|    So_Close,_So_Far|   link|
# |    null|13969544| 64|        other-google|    So_Close,_So_Far|  other|
# |    null|13969544| 17|     other-wikipedia|    So_Close,_So_Far|  other|
# |19824496|20935744| 14|            Fornever|So_Close,_So_Far_...|   link|
# |    null|20935744| 11|        other-google|So_Close,_So_Far_...|  other|
# |    null|27617970| 75|        other-google|So_Close_(Hall_&_...|  other|
# | 6028056|27617970| 57|Hall_&_Oates_disc...|So_Close_(Hall_&_...|   link|
# |    null|27617970| 14|         other-empty|So_Close_(Hall_&_...|  other|
# | 7385430|27617970| 42|    Change_of_Season|So_Close_(Hall_&_...|   link|
# |43626507|27617970| 10|Ultimate_Daryl_Ha...|So_Close_(Hall_&_...|   link|
# |    null|23776661| 29|        other-google|    So_Close_(album)|  other|
# | 4704298|23776661| 80|        Dina_Carroll|    So_Close_(album)|   link|
# | 1369965|26171131| 84|   Breaking_Benjamin|      So_Cold_(song)|   link|
# | 3308279|26171131| 33|        Blow_Me_Away|      So_Cold_(song)|   link|
# |30863868|26171131| 49|    Benjamin_Burnley|      So_Cold_(song)|   link|
# |25908257|26171131|163|Breaking_Benjamin...|      So_Cold_(song)|   link|
# | 2343166|26171131| 15|Live_EP_(Breaking...|      So_Cold_(song)|   link|
# |    null|26171131| 10|          other-bing|      So_Cold_(song)|  other|
# | 2034547|26171131|142|We_Are_Not_Alone_...|      So_Cold_(song)|   link|
# |24990537|26171131| 39|             So_Cold|      So_Cold_(song)|   link|
# |25228317|26171131| 19|Sooner_or_Later_(...|      So_Cold_(song)|   link|
# | 5203666|26171131| 15|Phobia_(Breaking_...|      So_Cold_(song)|   link|
# | 1577533|26171131| 46|Saturate_(Breakin...|      So_Cold_(song)|   link|
# |32269425|26171131| 12|Shallow_Bay:_The_...|      So_Cold_(song)|   link|
# |    null|26171131| 20|     other-wikipedia|      So_Cold_(song)|  other|
# |    null|26171131|443|        other-google|      So_Cold_(song)|  other|
# |    null|26171131| 58|         other-empty|      So_Cold_(song)|  other|
# |  198333|    null| 15|      The_Communards|   So_Cold_the_Night|redlink|
# |    null|33428912| 24|         other-empty|             So_Cool|  other|
# |38430995|32792554| 12|               Soyou|So_Cool_(Sistar_a...|   link|
# |38431291|32792554| 12|           Kim_Dasom|So_Cool_(Sistar_a...|   link|
# | 6504142|32792554| 15|         Kim_Heechul|So_Cool_(Sistar_a...|  other|
# |33063167|32792554| 21|List_of_Korea_K-P...|So_Cool_(Sistar_a...|  other|
# |35492870|32792554| 21|          Alone_(EP)|So_Cool_(Sistar_a...|   link|
# |34298538|32792554| 30|How_Dare_You_(Sis...|So_Cool_(Sistar_a...|   link|
# |38904459|32792554| 27|List_of_songs_rec...|So_Cool_(Sistar_a...|   link|
# |    null|32792554| 40|         other-empty|So_Cool_(Sistar_a...|  other|
# |32792554|32792554| 60|So_Cool_(Sistar_a...|So_Cool_(Sistar_a...|  other|
# |29541147|32792554|326|              Sistar|So_Cool_(Sistar_a...|   link|
# |35461524|32792554|240|  Sistar_discography|So_Cool_(Sistar_a...|   link|
# |    null|32792554| 57|     other-wikipedia|So_Cool_(Sistar_a...|  other|
# |    null|32792554|288|        other-google|So_Cool_(Sistar_a...|  other|
# |    null|11668721| 12|        other-google|So_Cool_(Take_6_a...|  other|
# |  657774|11668721| 39|              Take_6|So_Cool_(Take_6_a...|   link|
# |11668678|11668721| 14|Brothers_(Take_6_...|So_Cool_(Take_6_a...|   link|
# |    null|43266543| 11|         other-empty|              So_Cow|  other|
# |    null|43266543| 50|        other-google|              So_Cow|  other|
# |  209063|33419784| 92|        Achtung_Baby|            So_Cruel|   link|
# | 3557036|33419784| 11|Depeche_Mode_disc...|            So_Cruel|   link|
# |33390060|33419784| 11|AHK-toong_BAY-bi_...|            So_Cruel|   link|
# +--------+--------+---+--------------------+--------------------+-------+
# only showing top 100 rows
